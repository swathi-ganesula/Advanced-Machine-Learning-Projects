# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\91918\miniconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\91918\appdata\roaming\python\python313\site-packages (from xgboost) (2.3.3)
# Requirement already satisfied: scipy in c:\users\91918\appdata\roaming\python\python313\site-packages (from xgboost) (1.16.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfwine=pd.read_csv(r"C:\Users\91918\OneDrive\Desktop\Advanced Ml\datasets\wine.csv")

# %%
dfwine
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %% [markdown]
# ## Feature Engineering

# %%
dfwine.shape
# Out:
# (178, 14)

# %% [markdown]
# ### NaNs

# %%
dfwine.isna().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %% [markdown]
# ### Error Detection

# %%
dfwine["Wine"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
dfwine["Wine"].unique()
# Out:
# array([1, 2, 3])

# %%
dfwine["Wine"].value_counts()
# Out:
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
sns.boxplot(dfwine)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.boxplot(dfwine)
plt.xticks(rotation=90)
plt.show()

# %%
dfwine.columns
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
cols=['Malic.acid', 'Ash', 'Acl', 'Mg', 'Proanth', 'Color.int', 'Hue']    #these are the cols with errors

# %%
for c in cols:
    print(c)
# Out:
# Malic.acid
# Ash
# Acl
# Mg
# Proanth
# Color.int
# Hue

# %%
for c in cols:
    print(dfwine[c])
# Out:
# 0      1.71
# 1      1.78
# 2      2.36
# 3      1.95
# 4      2.59
#        ...
# 173    5.65
# 174    3.91
# 175    4.28
# 176    2.59
# 177    4.10
# Name: Malic.acid, Length: 178, dtype: float64
# 0      2.43
# 1      2.14
# 2      2.67
# 3      2.50
# 4      2.87
#        ...
# 173    2.45
# 174    2.48
# 175    2.26
# 176    2.37
# 177    2.74
# Name: Ash, Length: 178, dtype: float64
# 0      15.6
# 1      11.2
# 2      18.6
# 3      16.8
# 4      21.0
#        ...
# 173    20.5
# 174    23.0
# 175    20.0
# 176    20.0
# 177    24.5
# Name: Acl, Length: 178, dtype: float64
# 0      127
# 1      100
# 2      101
# 3      113
# 4      118
#       ...
# 173     95
# 174    102
# 175    120
# 176    120
# 177     96
# Name: Mg, Length: 178, dtype: int64
# 0      2.29
# 1      1.28
# 2      2.81
# 3      2.18
# 4      1.82
#        ...
# 173    1.06
# 174    1.41
# 175    1.35
# 176    1.46
# 177    1.35
# Name: Proanth, Length: 178, dtype: float64
# 0       5.64
# 1       4.38
# 2       5.68
# 3       7.80
# 4       4.32
#        ...
# 173     7.70
# 174     7.30
# 175    10.20
# 176     9.30
# 177     9.20
# Name: Color.int, Length: 178, dtype: float64
# 0      1.04
# 1      1.05
# 2      1.03
# 3      0.86
# 4      1.04
#        ...
# 173    0.64
# 174    0.70
# 175    0.59
# 176    0.60
# 177    0.61
# Name: Hue, Length: 178, dtype: float64

# %%
for c in cols:
    q1=dfwine[c].quantile(0.25)
    q3=dfwine[c].quantile(0.75)
    iqr=q3-q1
    lower=q1-(1.5*iqr)
    upper=q3+(1.5*iqr)
    dfwine[c]=dfwine[c].map(lambda x: lower if x < lower else upper if x>upper else x)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(dfwine)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Encoding

# %%
dfwine.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                      float64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %% [markdown]
# ### Data Seperation

# %%
dfwine.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
X=dfwine.drop("Wine",axis=1)

# %%
X.shape
# Out:
# (178, 13)

# %%
X
# Out:
#      Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0      14.23      1.7100  2.43  15.6  127.0     2.80        3.06
# 1      13.20      1.7800  2.14  11.2  100.0     2.65        2.76
# 2      13.16      2.3600  2.67  18.6  101.0     2.80        3.24
# 3      14.37      1.9500  2.50  16.8  113.0     3.85        3.49
# 4      13.24      2.5900  2.87  21.0  118.0     2.80        2.69
# ..       ...         ...   ...   ...    ...      ...         ...
# 173    13.71      5.3025  2.45  20.5   95.0     1.68        0.61
# 174    13.40      3.9100  2.48  23.0  102.0     1.80        0.75
# 175    13.27      4.2800  2.26  20.0  120.0     1.59        0.69
# 176    13.17      2.5900  2.37  20.0  120.0     1.65        0.68
# 177    14.13      4.1000  2.74  24.5   96.0     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 13 columns]

# %%
y=dfwine["Wine"]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %% [markdown]
# ### Imbalance

# %%
dfwine.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
y.value_counts()
# Out:
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
y.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Wine'>

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros=RandomOverSampler()

# %%
ros
# Out:
# RandomOverSampler()

# %%
X_ros,y_ros=ros.fit_resample(X,y)

# %%
X_ros.shape
# Out:
# (213, 13)

# %%
X.shape
# Out:
# (178, 13)

# %%
y.value_counts()
# Out:
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
y_ros.value_counts()
# Out:
# Wine
# 1    71
# 2    71
# 3    71
# Name: count, dtype: int64

# %%
y_ros.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Wine'>

# %%
y_ros.replace([1,2,3],[0,1,2],inplace=True)

# %% [markdown]
# ### Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_ros,y_ros,test_size=0.20,random_state=2)

# %%
X_ros.shape
# Out:
# (213, 13)

# %%
X_train.shape
# Out:
# (170, 13)

# %%
X_test.shape
# Out:
# (43, 13)

# %% [markdown]
# ### XGBoostClassifier

# %%
from xgboost import XGBClassifier

# %%
xgb_model=XGBClassifier(n_estimators=200)

# %%
xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_model.score(X_test,y_test)
# Out:
# 0.9534883720930233

# %% [markdown]
# ### Ensemble Model Function

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %%
def ensemble_model(X1,X2,y1,y2):
    rfc1=RandomForestClassifier()
    ada1=AdaBoostClassifier()
    xgb1=XGBClassifier()
    models= [rfc1, ada1, xgb1]
    score=[]
    for m in models:
        m.fit(X1,y1)
        sc=m.score(X2,y2)
        score.append(sc)
    print(score)
    return np.mean(score)

# %%
ensemble_model(X_train, X_test, y_train, y_test)
# Out:
# [1.0, 0.9767441860465116, 0.9534883720930233]
# np.float64(0.9767441860465116)
